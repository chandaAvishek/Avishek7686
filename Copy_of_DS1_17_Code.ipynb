# %% [markdown]
# <a href="https://colab.research.google.com/github/chandaAvishek/Avishek7686/blob/main/Copy_of_DS1_17_Code.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **INSTALLATION**

# %%
pip install pandas numpy matplotlib seaborn

# %% [markdown]
# ##### Download the Data

# %%
url = 'https://raw.githubusercontent.com/chandaAvishek/DS-17/refs/heads/main/social_media_vs_productivity.csv'

# %% [markdown]
# ##### Data Preparation and cleaning

# %%
import pandas as pd
df = pd.read_csv(url)
print(df)
# Out:
#        age  gender    job_type  daily_social_media_time  \
# 0       56    Male  Unemployed                 4.180940
# 1       46    Male      Health                 3.249603
# 2       32    Male     Finance                 3.025913
# 3       60  Female  Unemployed                 3.025913
# 4       25    Male          IT                 3.025913
# ...    ...     ...         ...                      ...
# 29995   34  Female      Health                 1.877297
# 29996   39    Male      Health                 4.437784
# 29997   42    Male   Education                17.724981
# 29998   20  Female   Education                 3.796634
# 29999   44    Male  Unemployed                 3.025913
#
#       social_platform_preference  number_of_notifications  work_hours_per_day  \
# 0                       Facebook                       61            6.753558
# 1                        Twitter                       59            9.169296
# ...

# %%
print("INFORMATION",df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30000 entries, 0 to 29999
# Data columns (total 19 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   age                             30000 non-null  int64
#  1   gender                          30000 non-null  object
#  2   job_type                        30000 non-null  object
#  3   daily_social_media_time         30000 non-null  float64
#  4   social_platform_preference      30000 non-null  object
#  5   number_of_notifications         30000 non-null  int64
#  6   work_hours_per_day              30000 non-null  float64
#  7   perceived_productivity_score    30000 non-null  float64
#  8   actual_productivity_score       30000 non-null  float64
#  9   stress_level                    30000 non-null  float64
#  10  sleep_hours                     30000 non-null  float64
#  11  screen_time_before_sleep        30000 non-null  float64
# ...

# %%
print("DESCRIPTION", df.describe())
# Out:
# DESCRIPTION                 age  daily_social_media_time  number_of_notifications  \
# count  30000.000000             30000.000000             30000.000000
# mean      41.486867                 3.105353                59.958767
# std       13.835221                 1.977046                 7.723772
# min       18.000000                 0.000000                30.000000
# 25%       30.000000                 1.797748                55.000000
# 50%       41.000000                 3.025913                60.000000
# 75%       53.000000                 4.219533                65.000000
# max       65.000000                17.973256                90.000000
#
#        work_hours_per_day  perceived_productivity_score  \
# count        30000.000000                  30000.000000
# mean             6.990792                      5.511269
# std              1.997736                      1.968287
# min              0.000000                      2.000252
# ...

# %%
missing_percentages = df.isna().sum().sort_values(ascending=False)/len(df)*100
print(missing_percentages)
# Out:
# age                               0.0
# gender                            0.0
# job_type                          0.0
# daily_social_media_time           0.0
# social_platform_preference        0.0
# number_of_notifications           0.0
# work_hours_per_day                0.0
# perceived_productivity_score      0.0
# actual_productivity_score         0.0
# stress_level                      0.0
# sleep_hours                       0.0
# screen_time_before_sleep          0.0
# breaks_during_work                0.0
# uses_focus_apps                   0.0
# has_digital_wellbeing_enabled     0.0
# coffee_consumption_per_day        0.0
# days_feeling_burnout_per_month    0.0
# weekly_offline_hours              0.0
# job_satisfaction_score            0.0
# dtype: float64

# %% [markdown]
# # Performing EDA:
#
# 1. daily_social_media_time
# 2. perceived_productivity_score
# 3. actual_productivity_score
# 4. number_od_notifications

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

numerical_columns = [
    'daily_social_media_time',
    'perceived_productivity_score',
    'actual_productivity_score',
    'number_of_notifications'
]

for col in numerical_columns:
  plt.figure(figsize=(10,6))
  sns.histplot(df[col], kde =True)
  plt.title(f'Distribution of {col.replace("_", " ").title()}', fontsize=16)
  plt.xlabel(col.replace("_", " ").title(), fontsize=14)
  plt.ylabel('Frequency', fontsize=14)
  plt.grid(axis='y')
  plt.tight_layout()
  plt.savefig(f'{col}_histogram.png')
  plt.show()

# %% [markdown]
# ##### Data exploration and Visualisation

# %%
df.columns
# Out:
# Index(['age', 'gender', 'job_type', 'daily_social_media_time',
#        'social_platform_preference', 'number_of_notifications',
#        'work_hours_per_day', 'perceived_productivity_score',
#        'actual_productivity_score', 'stress_level', 'sleep_hours',
#        'screen_time_before_sleep', 'breaks_during_work', 'uses_focus_apps',
#        'has_digital_wellbeing_enabled', 'coffee_consumption_per_day',
#        'days_feeling_burnout_per_month', 'weekly_offline_hours',
#        'job_satisfaction_score'],
#       dtype='object')

# %% [markdown]
# Column we will analyse
#
#
# 1.   daily_social_media_time
# 2.   actual_productivity_score
# 3.   number_of_notification
# 4.   weekly_offline_hours

# %%
df.actual_productivity_score.agg(['min','max','mean','median'])
# Out:
# min       0.296812
# max       9.846258
# mean      4.951800
# median    4.951742
# Name: actual_productivity_score, dtype: float64

# %%
df.daily_social_media_time.agg(['min','max','mean','median'])
# Out:
# min        0.000000
# max       17.973256
# mean       3.105353
# median     3.025913
# Name: daily_social_media_time, dtype: float64

# %%
df.number_of_notifications.agg(['min','max','mean','median'])
# Out:
# min       30.000000
# max       90.000000
# mean      59.958767
# median    60.000000
# Name: number_of_notifications, dtype: float64

# %%
df.weekly_offline_hours.agg(['min','max','mean','median'])
# Out:
# min        0.000000
# max       40.964769
# mean      10.360655
# median    10.013677
# Name: weekly_offline_hours, dtype: float64
